# %%
question = """what is the frequency of GymLink ?
Is Polar heart rate sensor enough to use on its own or do we need a separate application?
Can we wash the polar strap at 45 degrees Celsius after bleaching it?
Tell me about menopause depression
Which ML model works best while working with raw data for menopause depression?
svm works best for binary classification.Can we create a good ml model for multiclasification using SVM?
What are the minimum hardware requirements to run ARTSENs?
which pulse waveforms are displayed while measuring using ARTSENS?
which pulse waveforms are displayed while measuring using ARTSENS?
Is there any device which can be used to predict any future cardiovascular problems?
Is there any device which can be used to predict any future cardiovascular problems?
Tell me about the PWV device?
What is Audioverse?
Which model can be used for voice cloning?
How is BARK different from normal TTS architecture?
Can fourier transform be used foranalyzing sleep spectograms
What is Sleep apnea?
Tell me how titration is used with polysomnograms?
Uses of Polysomniograph?
Can antiphospholipid syndrome cause cardiovascular risk
Tell me about the paper by Ikdahl in 2016 and the long-term effects of rosuvastatinon arterial stiffness and blood pressure.
Tell me about 11 ways to prevent diabetes
Tell me about the potential management strategies to manage Cardiovascular disease risk in patients
I have diabetes can I drink coffee? It has sugar so I shouldnt consume it right? 
Can managing carb intake help reverse diabetes?
What is PPGF and how to calculate it?
What is Arm Cuff?
How many sets of measurement data can be stored in the bp monitor devices' memory?
Difference between UA-767PC 
Analysis Software (UA-767P-13) and TM-2480?"
Tell me about Carotid pressure measurement theory?
How is carotid/central blood pressure measured in ARTSENS?
Can Welch's t-test be used for data analysis?
Can we create a cuffless BP measurement technique using a high-frame-rate image-free ultrasound system?
What is cfPWV?
Can ARTSENS be integrated with BP machine?What's its application? 
What does the Linear regression plots illustrating correlation between cfPWV (SphygmoCor) and cfPWV indicate?""".split("\n")

# %%
question
# Out:
# ['what is the frequency of GymLink ?',
#  'Is Polar heart rate sensor enough to use on its own or do we need a separate application?',
#  'Can we wash the polar strap at 45 degrees Celsius after bleaching it?',
#  'Tell me about menopause depression',
#  'Which ML model works best while working with raw data for menopause depression?',
#  'svm works best for binary classification.Can we create a good ml model for multiclasification using SVM?',
#  'What are the minimum hardware requirements to run ARTSENs?',
#  'which pulse waveforms are displayed while measuring using ARTSENS?',
#  'which pulse waveforms are displayed while measuring using ARTSENS?',
#  'Is there any device which can be used to predict any future cardiovascular problems?',
#  'Is there any device which can be used to predict any future cardiovascular problems?',
#  'Tell me about the PWV device?',
#  'What is Audioverse?',
#  'Which model can be used for voice cloning?',
# ...

# %%
import os
from mechanics.retrieval_mechs import *
from r5_query_llm import *
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
answers = []
for ques in question:
    query = ques.strip().lower()
    raptor_response = raptor_retrieve(query, summary_tree, top_k_root=1, top_k_children=2)

    if not raptor_response:
        print("❌ No relevant information found. Try rephrasing your question.")
        continue

    results = raptor_response[:int(os.getenv("MAX_RETRIEVED_CHUNKS", 5))]
    print(f"📚 Found {len(raptor_response)} relevant chunks across hierarchy levels")
    print("\n🤖 Generating comprehensive answer...\n")

    answer = answer_llm(query, results, show_sources=True)
    answers.append(answer)
    print("✅ Answer generated successfully!\n")
    print("--------------------------------------------------\n")
# Out:
# 2025-11-03 12:06:32,689 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-03 12:06:32,952 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-03 12:06:33,221 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-03 12:06:33,493 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-03 12:06:33,499 - INFO - Processing question with 5 chunks from 5 sources
# 📚 Found 5 relevant chunks across hierarchy levels
#
# 🤖 Generating comprehensive answer...
# 2025-11-03 12:06:34,085 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 404 Not Found"
# 2025-11-03 12:06:34,086 - ERROR - LLM error: model 'gpt-oss:20b' not found (status code: 404)
# ❌ Error generating answer: model 'gpt-oss:20b' not found (status code: 404)
# Please check if Ollama is running and the model 'gpt-oss:20b' is available.
# ...
